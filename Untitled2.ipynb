# %% [markdown]
# <a href="https://colab.research.google.com/github/a49cmFfknfm/CS201-HW1-AlgDS/blob/master/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math

#1
print(77**(1/5) + 98**(1/3))
print((8+6**(1/2))**(1/3))
print((5**(1/8) + 13**(1/3)) / (2**8 + 143**(1/7)))
print(math.sin(3))
print(math.asin(-2/3))
print((math.cos(3) + math.sin(2)) / math.tan(7))
print(math.sin(2 * math.pi)**2)
print((math.asin(-1/2) + math.acos(-3/4)) / math.tan(2 * math.pi))
print(math.log(10, 3))
print(math.log(17))

#2.1
a = 4342
x = float(input("x="))
y1 = x**6 - 2*x**4 + 4*x + 7
print(f"Polynomial 1: {y1}")
y2 = 3*x**6 - 2*x**5 + 4*x**4 + 7*x**3 - 4*x - 5
print(f"Polynomial 2: {y2}")
y3 = 2*x**8 - 4*x**6 - 34*x**4 + x + 18
print(f"Polynomial 3: {y3}")
y4 = a*x**6 - 2*x**5 + 4*a*x**4 + 7*x**3 + x**2 - 4*x - a
print(f"Polynomial 4 (a={a}): {y4}")

#2.2
first_name = input("Enter first name: ")
last_name = input("Enter last name: ")
middle_name = input("Enter middle name (patronymic): ")
full_name = f"{first_name} {middle_name} {last_name}"
print(f"Hello, dear {full_name}")
print(f"Hello, dear {full_name} - and state that \n Dear {first_name} {middle_name}, you have a new message.")


#2.3
print(first_name [1])
print(first_name[1:3])

#2.4
a = "122129"
print(a.isdigit())
b = "jacob"
print(b.isdigit())
print(b.isalpha())
print(b[0].isupper())
print(b.capitalize())

#2.5
txt = input("Enter text: ")
total_kopecks = len(txt) * 70
hryvnias = total_kopecks // 100
kopecks = total_kopecks % 100
print(f"Cost: {hryvnias},{kopecks} UAH.")
# Out:
# 6.994391795513346
# 2.186242644538106
# 0.013851694500160149
# 0.1411200080598672
# -0.7297276562269663
# -0.09259883707859987
# 5.99903913064743e-32
# -7737984664221685.0
# 2.095903274289385
# 2.833213344056216
# x=354
# Polynomial 1: 1967943569356207.0
# Polynomial 2: 5892869556896491.0
# Polynomial 3: 4.932296321405888e+20
# Polynomial 4 (a=4342): 8.545208983155875e+18
# Enter first name: hiujbdfhbudfhuj
# Enter last name: dfhggh
# Enter middle name (patronymic): dfhghj
# Hello, dear hiujbdfhbudfhuj dfhghj dfhggh
# Hello, dear hiujbdfhbudfhuj dfhghj dfhggh - and state that
#  Dear hiujbdfhbudfhuj dfhghj, you have a new message.
# i
# iu
# True
# False
# True
# False
# Jacob
# Enter text: dfjkdfijkgfjkjgkfjksdjikfd
# Cost: 18,20 UAH.
